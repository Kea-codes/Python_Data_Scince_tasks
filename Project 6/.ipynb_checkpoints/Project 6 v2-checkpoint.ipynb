# %% [markdown]
# ## Project 6- MISY408

# %% [markdown]
# In this project you should examine Which Factors are significant in predicting Insurance **charges**.
#
# The folowing are the attributes of the dataset:
#
# **age:** age of primary beneficiary
#
# **sex:** gender of primary beneficiary
#
# **bmi:** body mass index of primary beneficiary
#
# **children:** Number of children covered by health insurance / Number of dependents.
#
# **smoker:** whther the person is smoker or non-smoker
#
# **region:** The beneficiary's residental area in the USA.
#
# **charges:** the price of health insurance

# %% [markdown]
# **Question 1:** Import Required libraries, load the dataset to df dataframe, display first 5 rows.

# %% [markdown]
# **Question 2:**
#
# a. Show the shape of the dataframe

# %% [markdown]
# b. Check for missing values and if there is any missing values drop them.

# %% [markdown]
# **Question 3: Exploratory data analysis**

# %% [markdown]
# a. Show the statistical summary of numerical variables (describe() method)

# %% [markdown]
# b. In the following, type a code to show average charges for each smiker group.

# %% [markdown]
# c. Interpret the above output. Do you think smoker can be a good predictor for charges? why?

# %% [markdown]
# d. In the following, type a code to show average charges for each sex.

# %% [markdown]
# e. Interpret the above output. Do you think 'sex' can be a good predictor for charges? why?

# %% [markdown]
# f. In the following, type a code to show average charges for each 'region'?

# %% [markdown]
# g. Interpret the above output. Do you think 'region' can be a good predictor for charges? why?

# %% [markdown]
# **Question 4**

# %% [markdown]
# a. Use get_dummies() method to encode the values of categorical columns to binary. Display the first 5 rows of df dataframe.

# %% [markdown]
# b. Create a correlation matrix of the variables in the df dataframe (color the background using background_gradient() )

# %% [markdown]
# **Question 5**

# %% [markdown]
# **Before you answer the next question, The followings are some suggestions and guides for you to build a good regression model:**
#
# First, check the correlation matrix, and select the features that have high correlation with 'charges'. To start, you can set X to only one feature and chack your R-Squared and Adj. R-Squared. To improve the model, add the next feature that has higher correlation with 'charges' compared to the other fearures, and check R-Squared and Adj. R-Squared. If you see both  R-Squared and Adj. R-Squared increased together and they did not deviate that much from each other, it is good. Also, check if the average error decreased compared to previous model. Check for multicollinearity and make sure the model does not have multicollinearity problem.  Next, to improve the model, add the next feature that has higher correlation with charges compared to the other fearures, check R-Squared and Adj. R-Squared and ... follow the same steps that I mentioned above after adding each feature to the model.
#
# You should come up with a model that fits the data best and has lowest average error as well. Your final X variables should result in the best model fit and lowest average error.
#
# **Note:** your final model should have at least 4 independent variables.

# %% [markdown]
# a. In the following, specify your final X and Y  (X is independent variables. Y is dependent variable)

# %% [markdown]
# b. Split the data to train-test (30 percent of data should be test set)

# %% [markdown]
# **Question 6**

# %% [markdown]
# a. Run OLS Regression model on train set

# %% [markdown]
# b. Before interpreting the results, Check whether your regression model on Train set has Multicollinearity problem.
#
# **Note:** if the model has multicollinearity problem, you should go back and remove the feature that causes that problem and probably add other feature/features.

# %% [markdown]
# c. Now that you are sure that your final model on train set does not have multicollinearity problem, Interpret the OLS regression results (R-Squared, Adj. R-Squared, Prob (F-statistic), coefficients of independent variables, p-values of independent variables, Average Error)

# %% [markdown]
# **Question 7**

# %% [markdown]
# a. Run Regression model on test set

# %% [markdown]
# b. Check whether your regression model on Test set has Multicollinearity problem

# %% [markdown]
# c. Does the model on test set have Multicollinearity problem? why?

# %% [markdown]
# d.Interpret the results of OLS regression model (R-Squared, Adj. R-Squared, Prob (F-statistic), coefficients of independent variables, p-values of independent variables, Average Error)

# %% [markdown]
# **Question 8: When you compare Train and Test results, is there any model overfitting problem? why?**
